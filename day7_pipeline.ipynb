# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
df=pd.read_csv('day7_data.csv')

# %%
df.head()
# Out:
#    Age   Income      City  House_Price
# 0   25  45000.0  New York       350000
# 1   68      NaN    London       420000
# 2   34  60000.0       NaN       380000
# 3   45  75000.0     Paris       410000
# 4   71      NaN  New York       480000

# %%
df.isnull().sum()
# Out:
# Age            0
# Income         8
# City           3
# House_Price    0
# dtype: int64

# %%
df.City.unique()
# Out:
# <StringArray>
# ['New York', 'London', nan, 'Paris']
# Length: 4, dtype: str

# %%
x = df.drop('House_Price',axis=1)

# %%
y=df.House_Price

# %%
from sklearn.model_selection import train_test_split as TTS

# %%
x_train,x_test,y_train,y_test=TTS(x,y,test_size=0.2,random_state=42)

# %%
#Creating pipeline

# %%
import numpy as np

# %%
num_cols=x.select_dtypes(include=[np.number]).columns.to_list()

# %%
cat_cols=x.select_dtypes(exclude=[np.number]).columns.to_list()

# %%
from sklearn.compose import ColumnTransformer as CT

# %%
from sklearn.pipeline import Pipeline, make_pipeline

# %%
from sklearn.impute import SimpleImputer

# %%
from sklearn.preprocessing import OneHotEncoder as OHE, RobustScaler

# %%
num_pipe=Pipeline([
    ('impute',SimpleImputer(strategy='median')),
    ('scaler',RobustScaler())
])

# %%
cat_pipe=Pipeline([
    ('impute',SimpleImputer(strategy='most_frequent')),
    ('Encoding',OHE(drop='first',handle_unknown='ignore',sparse_output=False))
])

# %%
preprocessor=CT([
    ('num',num_pipe,num_cols),
    ('cat',cat_pipe,cat_cols)
],remainder='passthrough')

# %%
model=LR()

# %%
pipe=make_pipeline(preprocessor,model)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   ['Age', 'Income']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('Encoding',
# ...

# %%
pred=pipe.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,pred)

# %%
print(f'ModelScore-> {score}')
# Out:
# ModelScore-> 0.28711813811084996

# %%
#Note-We just applied this to learn how to create pipeline, score will be low.

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
#Exported pipeline! This can be now used further for deployment purposes easily :)
